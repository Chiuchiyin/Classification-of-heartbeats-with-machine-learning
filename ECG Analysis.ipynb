# %%
from IPython.display import display
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import os
import shutil
import posixpath
import wfdb as wf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       6 import shutil
#       7 import posixpath
# ----> 8 import wfdb as wf
#
# ModuleNotFoundError: No module named 'wfdb'

# %%
record = wf.rdsamp('mitdb/100', sampto=3000)
annotation = wf.rdann('mitdb/100', 'atr', sampto=3000)
record[1]
# Out:
# {'fs': 360,
#  'sig_len': 3000,
#  'n_sig': 2,
#  'base_date': None,
#  'base_time': None,
#  'units': ['mV', 'mV'],
#  'sig_name': ['MLII', 'V5'],
#  'comments': ['69 M 1085 1629 x1', 'Aldomet, Inderal']}

# %%
fig, ax = plt.subplots(nrows=2, figsize=(12,6))
I = record[0][:, 0]
II = record[0][:, 1]

ax[0].plot(I)
ax[1].plot(II)
ax[0].set_ylabel('Lead II')
ax[1].set_xlabel('Datapoints')
ax[1].set_ylabel('Lead II')
# Out:
# Text(0, 0.5, 'Lead II')
